# %% [markdown]
# # S15 T01: Visualización interactiva con ElasticSearch Stack
#
# - **Descripción**
# Empezamos a familiarizarnos con la visualización interactiva de gráficos mediante Kibana.
# ___

# %%
# Libraries and modules
from PIL import Image

# %% [markdown]
# ## Nivel 1
# ### - Ejercicio 1
# Descárgate Kibana y muestra algunas gráficas utilizando conjuntos de datos de Ejemplo.
# ___

# %%
Image.open('1_Start_kibana.PNG')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1918x886 at 0x264FDA1B190>

# %% [markdown]
# - Se agrega un sample data de las opciones disponibles, en este caso se selecciono Sample flight data, por la familiaridad con el tipo de datos en sprints anteriores.

# %%
Image.open('2_Sample_data.PNG')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1918x933 at 0x264FD9BC970>

# %% [markdown]
# - Entre las primeras graficas creadas, se selecciono un grafico de barras correspondiente a las Aerolineas (Carrier) y la median de la distancia recorrida por sus vuelos. Se observa que todas ellas han recorrido distancias similares.

# %%
Image.open('barchart1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=924x372 at 0x264FDA1B8B0>

# %% [markdown]
# - Ahora se genera un grafico que muestra los vuelos cancelados por hora durante el mes de mayo.

# %%
Image.open('barchart2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=949x415 at 0x264FD9C86D0>

# %% [markdown]
# - Se genero un grafico que refleja la relacion entre el tiempo y la media de distancia recorrida por los vuelos.

# %%
Image.open('corplot.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=831x247 at 0x264FD9DF820>

# %% [markdown]
# - Se genero un mapa para observar los aeropuertos de Origen y Destino.

# %%
Image.open('geo_map.PNG')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1572x304 at 0x264FC7507C0>

# %% [markdown]
# - Se genero un heatmap que muestra la relacion entre el precio y los aeropuertos de destino y origen.

# %%
Image.open('heatmap.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=944x416 at 0x264FD9E5820>

# %% [markdown]
# - Por ultimo, se genero un grafico de pastel con los vuelos cancelados y el porcentaje de cancelaciones de la aerolinea.

# %%
Image.open('pie_chart.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=635x502 at 0x264FD9DF250>

# %% [markdown]
# ## Nivel 2
# ### - Ejercicio 1
# Implementa un dashboard que visualice interactivamente los datos que elijas .
# ___
# Se ha creado un dashboard utilizando distintos tipos de visualizacion que permite Kibana.

# %%
Image.open('Imagen1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1125x1169 at 0x264FDD3FEE0>

# %% [markdown]
# Ademas se han agregado formulas suncillas en la query para visualizar los datos con mayor claridad, como por ejemplo en la tabla de "Delayed fligths per carrier"

# %%
Image.open('Details1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1557x686 at 0x264FE367A30>

# %% [markdown]
# ## Nivel 3
# ### - Ejercicio 1
# Implementa un dashboard que genere gráficos utilizando cada uno de los distintos tipos de gráficos que ofrece Kibana.
# ___

# %% [markdown]
# Se han agregado filtros en la visualizacion de los datos entre las imagenes siguientes se puede observar la diferencia al aplicar los filtros. Se puede observar que la imagen ahora tiene mas records que la anterior, esto es porque se aumento el tiempo de visualizacion a un año.

# %%
Image.open('Imagen2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1125x1121 at 0x264FDD3FA30>

# %% [markdown]
# En esta ultima visualizacion, hemos filtrado por la ciudad de Origen: Barcelona y por el precio maximo de los vuelos.
# <br>
# ¿A donde se puede ir de Barcelona con un presupuesto de entre 100-500 euros?, basado en los vuelos del ultimo año.

# %%
Image.open('Imagen3.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1125x1170 at 0x264FDB60B50>
